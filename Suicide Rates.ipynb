# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("master.csv")
data.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.83  Albania1987           NaN      2,156,624,900
# 3               4.59  Albania1987           NaN      2,156,624,900
# 4               3.28  Albania1987           NaN      2,156,624,900
#
#    gdp_per_capita ($)       generation
# 0                 796     Generation X
# 1                 796           Silent
# 2                 796     Generation X
# 3                 796  G.I. Generation
# 4                 796          Boomers

# %%
data.tail()
# Out:
#           country  year     sex          age  suicides_no  population  \
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# 27815               2.96  Uzbekistan2014         0.675     63,067,077,179
# 27816               2.58  Uzbekistan2014         0.675     63,067,077,179
# 27817               2.17  Uzbekistan2014         0.675     63,067,077,179
# 27818               1.67  Uzbekistan2014         0.675     63,067,077,179
# 27819               1.46  Uzbekistan2014         0.675     63,067,077,179
#
#        gdp_per_capita ($)    generation
# 27815                2309  Generation X
# 27816                2309        Silent
# 27817                2309  Generation Z
# 27818                2309  Generation Z
# 27819                2309       Boomers

# %%
data.sample(5)
# Out:
#            country  year   sex          age  suicides_no  population  \
# 1992       Austria  2002  male  35-54 years          422     1214866
# 24802  Switzerland  2001  male  15-24 years           95      432247
# 8223   El Salvador  2004  male  15-24 years          108      540251
# 10565      Grenada  2005  male  25-34 years            1        7688
# 3192       Belarus  1990  male  15-24 years          132      702900
#
#        suicides/100k pop     country-year  HDI for year  gdp_for_year ($)   \
# 1992               34.74      Austria2002           NaN    213,377,771,504
# 24802              21.98  Switzerland2001           NaN    278,631,271,391
# 8223               19.99  El Salvador2004           NaN     13,724,810,900
# 10565              13.01      Grenada2005           NaN        695,370,296
# 3192               18.78      Belarus1990           NaN     21,650,000,000
#
#        gdp_per_capita ($)    generation
# 1992                27772       Boomers
# 24802               40582    Millenials
# 8223                 2573    Millenials
# 10565                7422  Generation X
# 3192                 2301  Generation X

# %%
data.sample(frac=0.1)
# Out:
#                    country  year     sex          age  suicides_no  \
# 9569               Georgia  2001    male  35-54 years           23
# 9707               Georgia  2015  female  15-24 years            2
# 11820              Iceland  1997    male  35-54 years           10
# 13395                Japan  1987    male  15-24 years         1065
# 5114                Canada  2001  female  55-74 years          161
# 13650                Japan  2008    male   5-14 years           41
# 24227             Suriname  2003    male  35-54 years           15
# 16229            Mauritius  1988  female    75+ years            0
# 752              Argentina  1998  female  35-54 years          147
# 10921            Guatemala  2004    male  15-24 years           72
# 24873          Switzerland  2007    male  35-54 years          297
# 8582               Estonia  2014    male    75+ years           26
# 23528                Spain  1985    male    75+ years          305
# 16757               Mexico  2001    male  25-34 years          837
# 19373             Portugal  1986    male  25-34 years           65
# 22390           Seychelles  2015    male  15-24 years            1
# 6942                Cyprus  2004    male  55-74 years            2
# 10629              Grenada  2010    male  25-34 years            0
# 26707       United Kingdom  2004    male  55-74 years          601
# 22634            Singapore  2004  female  35-54 years           52
# 2705               Bahrain  1999    male   5-14 years            0
# 18037               Norway  2000    male  25-34 years           80
# 25062             Thailand  1995    male  25-34 years          931
# 16722               Mexico  1998    male  15-24 years          860
# 4474                Brazil  2010    male  25-34 years         1832
# 25887         Turkmenistan  2000    male    75+ years            0
# 25907         Turkmenistan  2002  female  55-74 years            6
# 578    Antigua and Barbuda  2015  female  25-34 years            0
# 14414               Kuwait  2009  female  15-24 years            3
# 21383          Saint Lucia  1993  female  15-24 years            0
# ...                    ...   ...     ...          ...          ...
# 7352        Czech Republic  2011    male  15-24 years          120
# 25140             Thailand  2002  female    75+ years           43
# 14514           Kyrgyzstan  1992    male   5-14 years           11
# 2685               Bahrain  1998  female  25-34 years            0
# 1507             Australia  1991  female  15-24 years           84
# 3597               Belgium  1998    male  35-54 years          571
# 2516       9,055,290,000               30671       Millenials
# 20048    103,143,500,000               29728       Millenials
# 4909       1,864,824,081                4124          Boomers
# 1702     926,448,240,318               45128          Boomers
# 9142   1,025,211,803,414               19558          Boomers
# 26004     22,583,157,895                4962     Generation Z
# 5578     252,251,992,029               15854       Millenials
# 8492      16,963,625,016               13264           Silent
# 17352    936,228,211,513               60375     Generation Z
# 9574       3,219,487,747                 777     Generation X
# 2378       2,713,999,900               12286  G.I. Generation
# 1371       2,623,726,257               27672       Millenials
# 25856      2,605,688,065                 636           Silent
# 4096       1,487,005,600                5098     Generation Z
# 12242     99,853,528,653               28340     Generation X
# 22882     30,703,017,450                6020           Silent
# 22915     46,731,767,494                9138       Millenials
# 26067     35,799,628,571                7326           Silent
# 24328      4,422,276,622                9184          Boomers
# 25899      3,534,803,922                 863           Silent
# 8861     126,833,123,354               26296           Silent
#
# [2782 rows x 12 columns]

# %%
data.describe()
# Out:
#                year   suicides_no    population  suicides/100k pop  \
# count  27820.000000  27820.000000  2.782000e+04       27820.000000
# mean    2001.258375    242.574407  1.844794e+06          12.816097
# std        8.469055    902.047917  3.911779e+06          18.961511
# min     1985.000000      0.000000  2.780000e+02           0.000000
# 25%     1995.000000      3.000000  9.749850e+04           0.920000
# 50%     2002.000000     25.000000  4.301500e+05           5.990000
# 75%     2008.000000    131.000000  1.486143e+06          16.620000
# max     2016.000000  22338.000000  4.380521e+07         224.970000
#
#        HDI for year  gdp_per_capita ($)
# count   8364.000000        27820.000000
# mean       0.776601        16866.464414
# std        0.093367        18887.576472
# min        0.483000          251.000000
# 25%        0.713000         3447.000000
# 50%        0.779000         9372.000000
# 75%        0.855000        24874.000000
# max        0.944000       126352.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27820 entries, 0 to 27819
# Data columns (total 12 columns):
# country               27820 non-null object
# year                  27820 non-null int64
# sex                   27820 non-null object
# age                   27820 non-null object
# suicides_no           27820 non-null int64
# population            27820 non-null int64
# suicides/100k pop     27820 non-null float64
# country-year          27820 non-null object
# HDI for year          8364 non-null float64
#  gdp_for_year ($)     27820 non-null object
# gdp_per_capita ($)    27820 non-null int64
# generation            27820 non-null object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 2.5+ MB

# %%
data.columns
# Out:
# Index(['country', 'year', 'sex', 'age', 'suicides_no', 'population',
#        'suicides/100k pop', 'country-year', 'HDI for year',
#        ' gdp_for_year ($) ', 'gdp_per_capita ($)', 'generation'],
#       dtype='object')

# %%
data = data.rename(columns={'country':'Country','year':'Year','sex':'Gender','age':'Age','suicides_no':'SuicidesNo',
                           'population':'Population','suicides/100k pop':'Suicides100kPop','country-year':'CountryYear',
                           'HDI for year':'HDIForYear',' gdp_for_year ($) ':'GdpForYearMoney',
                            'gdp_per_capita ($)':'GdpPerCapitalMoney','generation':'Generation'})
data.columns
# Out:
# Index(['Country', 'Year', 'Gender', 'Age', 'SuicidesNo', 'Population',
#        'Suicides100kPop', 'CountryYear', 'HDIForYear', 'GdpForYearMoney',
#        'GdpPerCapitalMoney', 'Generation'],
#       dtype='object')

# %%
data.shape
# Out:
# (27820, 12)

# %%
data.isnull().any()
# Out:
# Country               False
# Year                  False
# Gender                False
# Age                   False
# SuicidesNo            False
# Population            False
# Suicides100kPop       False
# CountryYear           False
# HDIForYear             True
# GdpForYearMoney       False
# GdpPerCapitalMoney    False
# Generation            False
# dtype: bool

# %%
data.isnull().values.any()
# Out:
# True

# %%
data.isnull().sum()
# Out:
# Country                   0
# Year                      0
# Gender                    0
# Age                       0
# SuicidesNo                0
# Population                0
# Suicides100kPop           0
# CountryYear               0
# HDIForYear            19456
# GdpForYearMoney           0
# GdpPerCapitalMoney        0
# Generation                0
# dtype: int64

# %%
data = data.drop(['CountryYear','HDIForYear'],axis = 1)
data.head()
# Out:
#    Country  Year  Gender          Age  SuicidesNo  Population  \
# 0  Albania  1987    male  15-24 years          21      312900
# 1  Albania  1987    male  35-54 years          16      308000
# 2  Albania  1987  female  15-24 years          14      289700
# 3  Albania  1987    male    75+ years           1       21800
# 4  Albania  1987    male  25-34 years           9      274300
#
#    Suicides100kPop GdpForYearMoney  GdpPerCapitalMoney       Generation
# 0             6.71   2,156,624,900                 796     Generation X
# 1             5.19   2,156,624,900                 796           Silent
# 2             4.83   2,156,624,900                 796     Generation X
# 3             4.59   2,156,624,900                 796  G.I. Generation
# 4             3.28   2,156,624,900                 796          Boomers

# %%
min_year = min(data.Year)
max_year = max(data.Year)
print('Min_Year',min_year)
print('Max_Year',max_year)
# Out:
# Min_Year 1985
# Max_Year 2016

# %%
data_country = data[(data['Year'] == min_year)]
country_1985 = data[(data['Year'] == min_year)].Country.unique()
country_1985
# Out:
# array(['Antigua and Barbuda', 'Argentina', 'Australia', 'Austria',
#        'Bahamas', 'Bahrain', 'Barbados', 'Belgium', 'Brazil', 'Bulgaria',
#        'Canada', 'Chile', 'Colombia', 'Costa Rica', 'Dominica', 'Ecuador',
#        'France', 'Greece', 'Grenada', 'Iceland', 'Ireland', 'Israel',
#        'Italy', 'Jamaica', 'Japan', 'Kuwait', 'Luxembourg', 'Malta',
#        'Mauritius', 'Mexico', 'Netherlands', 'New Zealand', 'Panama',
#        'Paraguay', 'Portugal', 'Puerto Rico', 'Republic of Korea',
#        'Saint Vincent and Grenadines', 'Seychelles', 'Singapore', 'Spain',
#        'Sri Lanka', 'Suriname', 'Thailand', 'Trinidad and Tobago',
#        'United Kingdom', 'United States', 'Uruguay'], dtype=object)

# %%
country_male_1985 = []
country_female_1985 = []
for country in country_1985:
    country_male_1985.append(len(data_country[(data_country['Country'] == country)&(data_country['Gender'] == 'male')]))
    country_female_1985.append(len(data_country[(data_country['Country'] == country)&(data_country['Gender'] == 'female')]))

# %%
plt.figure(figsize=(10,10))
sns.barplot(x=country_male_1985,y=country_1985,color='red')
sns.barplot(x=country_female_1985,y=country_1985,color='yellow')
plt.xlabel('Count Male Vs Female')
plt.ylabel('Countries')
plt.title("1985 Year Suicide Rate Gender")
plt.show()

# %%
data_country=data[(data['Year']==max_year)]

country_2016=data[(data['Year']==max_year)].Country.unique()
country_2016_male=[]
country_2016_female=[]

for country in country_2016:
    country_2016_male.append(len(data_country[(data_country['Country']==country)&(data_country['Gender']=='male')]))
    country_2016_female.append(len(data_country[(data_country['Country']==country)&(data_country['Gender']=='female')])) 
    
plt.figure(figsize=(10,10))
sns.barplot(y=country_2016,x=country_2016_male,color='red')
sns.barplot(y=country_2016,x=country_2016_female,color='yellow')
plt.ylabel('Countries')
plt.xlabel('Count Male vs Female')
plt.title('2016 Year Suicide Rate Gender')
plt.show()

# %%
data_country=data[(data['Year']==min_year)]

country_1985_population=[]

for country in country_1985:
    country_1985_population.append(sum(data_country[(data_country['Country']==country)].Population))    


plt.figure(figsize=(10,10))
sns.barplot(y=country_1985,x=country_1985_population)
plt.xlabel('Population Count')
plt.ylabel('Countries')
plt.title('1985 Year Sum Population for Suicide Rate')
plt.show()

# %%
data_country = data[(data['Year'] == max_year)]
country_2016_population = []

for country in country_2016:
    country_2016_population.append(sum(data_country[(data_country['Country'] == country)].Population))

plt.figure(figsize=(10,10))
sns.barplot(x=country_2016_population,y=country_2016)
plt.xlabel("Population Count")
plt.ylabel("COuntries")
plt.title("2016 Year Sum Population Suicide rate")
plt.show()

# %%
data.Age.unique()
# Out:
# array(['15-24 years', '35-54 years', '75+ years', '25-34 years',
#        '55-74 years', '5-14 years'], dtype=object)

# %%
data_country = data[(data['Year'] == min_year)]

data_age_5_14 = []
data_age_15_24 = []
data_age_25_34 = []
data_age_35_54 = []
data_age_55_74 = []
data_age_75 = []

for country in data_country:
    data_age_5_14.append(len(data_country[(data_country['Country'] == country)&(data_country['Age'] == '5-14 years')]))
    data_age_15_24.append(len(data_country[(data_country['Country'] == country)&(data_country['Age'] == '15-24 years')]))
    data_age_25_34.append(len(data_country[(data_country['Country'] == country)&(data_country['Age'] == '25-34 years')]))
    data_age_35_54.append(len(data_country[(data_country['Country'] == country)&(data_country['Age'] == '35-54 years')]))
    data_age_55_74.append(len(data_country[(data_country['Country'] == country)&(data_country['Age'] == '55-74 years')]))
    data_age_75.append(len(data_country[(data_country['Country'] == country)&(data_country['Age'] == '75+ years')]))

# %%
data_country=data[(data['Year']==max_year)]

data_age_5_14=[]
data_age_15_24=[]
data_age_25_34=[]
data_age_35_54=[]
data_age_55_74=[]
data_age_75=[]

for country in country_2016:
        data_age_5_14.append(len(data_country[(data_country['Country']==country)&(data_country['Age']=='5-14 years')]))
        data_age_15_24.append(len(data_country[(data_country['Country']==country)&(data_country['Age']=='15-24 years')]))
        data_age_25_34.append(len(data_country[(data_country['Country']==country)&(data_country['Age']=='25-34 years')]))
        data_age_35_54.append(len(data_country[(data_country['Country']==country)&(data_country['Age']=='35-54 years')]))
        data_age_55_74.append(len(data_country[(data_country['Country']==country)&(data_country['Age']=='55-74 years')]))
        data_age_75.append(len(data_country[(data_country['Country']==country)&(data_country['Age']=='75+ years')]))

# %%
sns.countplot(data.Gender)
plt.show()

# %%
data.groupby("Age")['Gender'].count()
# Out:
# Age
# 15-24 years    4642
# 25-34 years    4642
# 35-54 years    4642
# 5-14 years     4610
# 55-74 years    4642
# 75+ years      4642
# Name: Gender, dtype: int64

# %%
sns.barplot(x=data.groupby("Age")['Gender'].count().index, y=data.groupby("Age")['Gender'].count().values)
plt.show()

# %%
suicidesNo = []
for country in data.Country.unique():
     suicidesNo.append(sum(data[data['Country'] == country].SuicidesNo))

suicidesNo = pd.DataFrame(suicidesNo,columns=['suicidesNo'])
country = pd.DataFrame(data.Country.unique(),columns=['country'])
data_suicide_country = pd.concat([suicidesNo,country],axis=1)
data_suicide_country = data_suicide_country.sort_values(by='suicidesNo',ascending=False)
sns.barplot(x=data_suicide_country.suicidesNo[:15],y=data_suicide_country.country[:15])
plt.show()

# %%
group_data = data.groupby(['Age','Gender'])['SuicidesNo'].sum().unstack()
group_data = group_data.reset_index().melt(id_vars='Age')
group_data
# Out:
#             Age  Gender    value
# 0   15-24 years  female   175437
# 1   25-34 years  female   208823
# 2   35-54 years  female   506233
# 3    5-14 years  female    16997
# 4   55-74 years  female   430036
# 5     75+ years  female   221984
# 6   15-24 years    male   633105
# 7   25-34 years    male   915089
# 8   35-54 years    male  1945908
# 9    5-14 years    male    35267
# 10  55-74 years    male  1228407
# 11    75+ years    male   431134

# %%
group_data1 = group_data[group_data['Age'] == '15-24 years']
sns.barplot(x=group_data1.Gender, y=group_data1.value)
plt.show()

# %%
sns.countplot(data.Generation)
plt.xticks(rotation=45)
plt.title("Generation Counter")
plt.show()

# %%
index_population = []
for age in data['Age'].unique():
    index_population.append(sum(data[data['Age'] == age].Population)/len(data[data['Age'] == age].Population))

sns.barplot(x=data["Age"].unique(),y=index_population)
plt.xticks(rotation=90)
plt.show()

# %%
sns.set(style='whitegrid')
sns.boxplot(data['Population'])
plt.show()

# %%
sns.set(style='whitegrid')
sns.boxplot(data['GdpPerCapitalMoney'])
plt.show()

# %%
sns.jointplot(x="Year",y='Suicides100kPop',data=data)
plt.show()
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\hp\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x='Population',y='SuicidesNo',data=data)
plt.show()
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\hp\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x="Year",y='GdpPerCapitalMoney',data=data,kind='reg')
plt.show()
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\hp\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x='Year',y='GdpPerCapitalMoney',data=data,kind='kde',height=7,space=0)
plt.show()
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\matplotlib\contour.py:960: UserWarning: The following kwargs were not used by contour: 'height'
#   s)

# %%
sns.jointplot(x='SuicidesNo',y='GdpPerCapitalMoney',data=data[data['Country'] == 'United States'],kind='hex')
plt.show()
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\hp\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot("Suicides100kPop", "SuicidesNo", data=data[data['Country']=='Russian Federation'], kind="kde",space=0,color='g')
plt.show()

# %%
sns.FacetGrid(data,hue='Year',size=5).map(plt.scatter,'GdpPerCapitalMoney','Population').add_legend()
plt.show()

# %%
sns.FacetGrid(data,hue='Generation',size=6).map(sns.kdeplot,'Population').add_legend()
plt.show()

# %%
sns.countplot(x='Generation',hue='Gender',data=data)
plt.xticks(rotation=45)
plt.show()

# %%
sns.stripplot(x=data['SuicidesNo'])
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.stripplot(x="Year",y="SuicidesNo",data=data)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.factorplot(x="SuicidesNo",y='Gender',kind='violin',data=data)
plt.show()

# %%
plt.scatter(x=np.arange(1,27821),y=data['Suicides100kPop'].values.tolist())
plt.show()

# %%
plt.scatter(x=np.arange(1,27821),y=data['SuicidesNo'].values.tolist())
plt.show()

# %%
plt.scatter(x=np.arange(1,27821),y=data['Population'].values.tolist())
plt.show()

# %%
plt.scatter(x=np.arange(1,27821),y=data['GdpPerCapitalMoney'].values.tolist())
plt.show()

# %%
sns.distplot(data['Suicides100kPop'])
plt.show()
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.set_color_codes()
sns.distplot(data['Country'].value_counts().values,color='red')
plt.show()
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.pairplot(data,hue='Generation')
plt.show()

# %%
sns.pairplot(data,hue='Gender')
plt.show()

# %%
sns.residplot('SuicidesNo','Suicides100kPop',data=data,lowess=True,color='red')
plt.show()

# %%
sns.violinplot(x=data['Generation'],y=data['Population'])
plt.show()

# %%
sns.heatmap(data.corr(),annot=True)
plt.show()

# %%
sns.heatmap(data.corr(), vmax=.3, center=1,
            square=True, linewidths=.5,annot=True)
plt.show()

# %%
sns.boxplot(x=data['Generation'],y=data['Population'])
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4, 5]), <a list of 6 Text xticklabel objects>)
